# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

# %%
Image_Width=128
Image_Height=128
Image_Size=(Image_Width,Image_Height)
Image_Channels=3

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Upload data and unzip
from zipfile import ZipFile

file_name = "/content/drive/MyDrive/Autism/archive.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
filenames = os.listdir("/content/data/train/")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'Autistic':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#        filename  category
# 0      Autistic         1
# 1  Non_Autistic         0

# %%
df.tail()
# Out:
#        filename  category
# 0      Autistic         1
# 1  Non_Autistic         0

# %%
df['category'].value_counts().plot.bar()

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive"
# Out:
# '495-Lecture 7.gslides'
#  498R-cryptocurrency
#  499-report.doc
#  499-report.gdoc
#  Aggression_detection
#  Aggression-detection2
#  annotation
#  Annotation-data
#  Appointment_Letter_shapna.docx
#  assignment
#  assignment1.zip
#  assignment.ipynb
#  assignment_ML
#  assignment_shapna.zip
#  Autism
# 'BANGLA OCR'
# 'bangla-ocr(image)'
#  BrainTumourClassification
#  certificates
#  Classroom
#  CNN
# 'Colab Notebooks'
#  colab-proj
#  conference-template-a4.docx
#  consent_form_1721568042.docx
# 'consent form.docx'
# 'Cooking vlog-shapna '
#  covid-certificate.pdf
#  Covid-Timeseries
#  CSE499A.Cryptocurrency
#  cse499presentation
#  cse499.USD
# 'cv (1).pdf'
# 'CV (1).pdf'
#  cv.docx
#  cv.pdf
#  CV.pdf
#  deeplearning
# 'DevOps Engineer.jpg'
#  Diabetes_prediction
# 'dogs-vs-cats '
# 'ECO Lecture -3.gdoc'
# 'Edited - 1721568042.pdf'
# 'emu8086.zip (Unzipped Files)'
#  finalExam_cse445.docx
#  FinalExam_mst.shapna-akter_1721568042.docx
#  finalNepal.xls
#  finalreport.rtf
# 'formalpic (1).png'
#  formalpic.png
#  full_traindata.zip
#  FUwangfood.ipynb
# 'Getting started.pdf'
#  GPT2-aggression
#  gpt3
# 'housing price prediction'
#  housingPrice_testDataHandle.ipynb
#  image.gif
#  implementation_LSTM
#  inceptiov3-network
#  LAB2_1721568042.zip
#  LAB4_1721568042.zip
#  labeledTrainData.tsv
#  localDrivefolders
#  mask
# 'mid -missing part.pdf'
#  midterm_1721568042.docx
#  midterm_ML
#  ML_midterm_1721568042.docx
#  ModelFile.zip
# 'mst shapna akter_1721568042.docx'
#  mst_shapna_akter_1721568042.docx
#  mst.shapna-akter_1721568042.docx
# 'mst shapna akter-1721568042-sec09.pdf'
#  mst.shapna-akter_1721568042.zip
# 'mst.shapna-akter_1721568042.zip (Unzipped Files)'
# 'Mst Shapna Akter_Lab Officer.pdf'
# 'Mst Shapna Akter-ML engineer.pdf'
# 'Mst Shapna Akter-part-time-LapOfficer.pdf'
# 'my pictures'
#  mysubssmooth.wav
# 'New folder.zip'
#  NLP_PROJECT
#  OCR_Traindata
#  OneshotDFU
#  overlap.ipynb
#  phi104_1721568042.docx
#  pickcle
#  practice-interview
#  pred.zip
# 'Project tracking.gsheet'
#  provisional.pdf
#  python-learning
#  Q2.gdoc
#  random-practice
#  research.7z
#  research-materials
# 'Resume (1).pdf'
# 'resume (2).pdf'
#  Resume.pdf
#  Review1.gdoc
#  Review2.gdoc
# 'review to_dipto6thaug_from shapna.zip'
# 'Schedule (1).gsheet'
#  Schedule.gsheet
#  sentimentAnalysis
# 'Set 95378.pdf'
#  shapna-finaldataset2.zip
#  shapna-finaldataset-3.zip
#  shapna-finaldataset-v4.zip
#  shapna-finaldataset.zip
#  shapna_MLmid
#  shy8yuugu.pdf
#  signature.pdf
#  skin_cancer
#  Skin-Cancer-Detector-using-CNN-master.zip
#  skin-cancer-video
#  stacking-ensemble.ipynb
#  STEM
# 'stock price '
#  stock-price-arima-sarima-cnn
#  stock_price_BILSTM
# 'stock price CNN'
#  StockPriceEnsembleDL
#  stock_price_ensemble_randomforrest
# 'stock price_LSTM'
# 'stock-price review'
#  student-analysis.gsheet
#  summery.pdf
#  tensorflowRT.ipynb
#  termpaper_1721568042.pdf
#  testing.ipynb
#  Text-Summerize
# 'To-do list.gsheet'
#  transcript.pdf
# 'translate all text into english'
# 'Untitled Diagram (1).drawio'
# 'Untitled Diagram (2).drawio'
# 'Untitled Diagram.drawio'
# 'Untitled Diagram.pdf'
# 'Untitled folder'
#  VisualizeCnnFilters

# %%
filepath1 = "/content/drive/MyDrive/Autism/weights/model1.h5"
filepath2 = "/content/drive/MyDrive/Autism/weights/model2.h5"
filepath3 = "/content/drive/MyDrive/Autism/weights/model3.h5"

filepath4 = "/content/drive/MyDrive/Autism/weights/model4.h5"
filepath5= "/content/drive/MyDrive/Autism/weights/model5.h5"

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,\
     Dropout,Flatten,Dense,Activation,\
     BatchNormalization

model1=Sequential()
model1.add(Conv2D(32,(3,3),activation='relu',input_shape=(Image_Width,Image_Height,Image_Channels)))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size=(2,2)))
model1.add(Dropout(0.25))
model1.add(Conv2D(64,(3,3),activation='relu'))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size=(2,2)))
model1.add(Dropout(0.25))
model1.add(Conv2D(128,(3,3),activation='relu'))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size=(2,2)))
model1.add(Dropout(0.25))
model1.add(Flatten())
model1.add(Dense(512,activation='relu'))
model1.add(BatchNormalization())
model1.add(Dropout(0.5))
model1.add(Dense(2,activation='softmax'))
model1.compile(loss='categorical_crossentropy',
  optimizer='rmsprop',metrics=['accuracy'])

# %%
model2=Sequential()
model2.add(Conv2D(32,(3,3),activation='relu',input_shape=(Image_Width,Image_Height,Image_Channels)))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(Dropout(0.25))
model2.add(Conv2D(64,(3,3),activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(Dropout(0.25))
model2.add(Conv2D(128,(3,3),activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(Dropout(0.25))
model2.add(Flatten())
model2.add(Dense(512,activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.5))
model2.add(Dense(2,activation='softmax'))
model2.compile(loss='categorical_crossentropy',
  optimizer='rmsprop',metrics=['accuracy'])

# %%
model3=Sequential()
model3.add(Conv2D(32,(3,3),activation='relu',input_shape=(Image_Width,Image_Height,Image_Channels)))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2,2)))
model3.add(Dropout(0.25))
model3.add(Conv2D(64,(3,3),activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2,2)))
model3.add(Dropout(0.25))
model3.add(Conv2D(128,(3,3),activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2,2)))
model3.add(Dropout(0.25))
model3.add(Flatten())
model3.add(Dense(512,activation='relu'))
model3.add(BatchNormalization())
model3.add(Dropout(0.5))
model3.add(Dense(2,activation='softmax'))
model3.compile(loss='categorical_crossentropy',
  optimizer='rmsprop',metrics=['accuracy'])

# %%
model4=Sequential()
model4.add(Conv2D(32,(3,3),activation='relu',input_shape=(Image_Width,Image_Height,Image_Channels)))
model4.add(BatchNormalization())
model4.add(MaxPooling2D(pool_size=(2,2)))
model4.add(Dropout(0.25))
model4.add(Conv2D(64,(3,3),activation='relu'))
model4.add(BatchNormalization())
model4.add(MaxPooling2D(pool_size=(2,2)))
model4.add(Dropout(0.25))
model4.add(Conv2D(128,(3,3),activation='relu'))
model4.add(BatchNormalization())
model4.add(MaxPooling2D(pool_size=(2,2)))
model4.add(Dropout(0.25))
model4.add(Flatten())
model4.add(Dense(512,activation='relu'))
model4.add(BatchNormalization())
model4.add(Dropout(0.5))
model4.add(Dense(2,activation='softmax'))
model4.compile(loss='categorical_crossentropy',
  optimizer='rmsprop',metrics=['accuracy'])

# %%
model5=Sequential()
model5.add(Conv2D(32,(3,3),activation='relu',input_shape=(Image_Width,Image_Height,Image_Channels)))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))
model5.add(Dropout(0.25))
model5.add(Conv2D(64,(3,3),activation='relu'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))
model5.add(Dropout(0.25))
model5.add(Conv2D(128,(3,3),activation='relu'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))
model5.add(Dropout(0.25))
model5.add(Flatten())
model5.add(Dense(512,activation='relu'))
model5.add(BatchNormalization())
model5.add(Dropout(0.5))
model5.add(Dense(2,activation='softmax'))
model5.compile(loss='categorical_crossentropy',
  optimizer='rmsprop',metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience = 10)
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_loss',patience = 2,verbose = 1,factor = 0.5,min_lr = 0.00001)
callbacks = [earlystop,learning_rate_reduction]

# %%
from distutils.dir_util import copy_tree
toDir = "AllTrain"
fromdir = "/content/data/train/Autistic"
copy_tree(fromdir ,toDir)
fromdirNon = "/content/data/train/Non_Autistic"
copy_tree(fromdirNon ,toDir)
# Out:
# ['AllTrain/0082.jpg',
#  'AllTrain/0423.jpg',
#  'AllTrain/1008.jpg',
#  'AllTrain/0651.jpg',
#  'AllTrain/0960.jpg',
#  'AllTrain/1133.jpg',
#  'AllTrain/0477.jpg',
#  'AllTrain/0154.jpg',
#  'AllTrain/0384.jpg',
#  'AllTrain/0191.jpg',
#  'AllTrain/0611.jpg',
#  'AllTrain/0673.jpg',
#  'AllTrain/0560.jpg',
#  'AllTrain/0148.jpg',
#  'AllTrain/0919.jpg',
#  'AllTrain/0861.jpg',
#  'AllTrain/0282.jpg',
#  'AllTrain/1084.jpg',
#  'AllTrain/1020.jpg',
#  'AllTrain/0959.jpg',
#  'AllTrain/0505.jpg',
#  'AllTrain/0380.jpg',
#  'AllTrain/1136.jpg',
#  'AllTrain/0781.jpg',
#  'AllTrain/1131.jpg',
#  'AllTrain/0586.jpg',
#  'AllTrain/0438.jpg',
#  'AllTrain/1182.jpg',
#  'AllTrain/0161.jpg',
#  'AllTrain/0099.jpg',
#  'AllTrain/0646.jpg',
#  'AllTrain/0012.jpg',
#  'AllTrain/0961.jpg',
#  'AllTrain/1122.jpg',
#  'AllTrain/0745.jpg',
#  'AllTrain/0239.jpg',
#  'AllTrain/0830.jpg',
#  'AllTrain/0795.jpg',
#  'AllTrain/0910.jpg',
#  'AllTrain/0010.jpg',
#  'AllTrain/0033.jpg',
#  'AllTrain/0709.jpg',
#  'AllTrain/1075.jpg',
#  'AllTrain/0758.jpg',
#  'AllTrain/0853.jpg',
#  'AllTrain/0366.jpg',
#  'AllTrain/0437.jpg',
#  'AllTrain/0184.jpg',
#  'AllTrain/0037.jpg',
#  'AllTrain/0205.jpg',
#  'AllTrain/0610.jpg',
#  'AllTrain/0606.jpg',
#  'AllTrain/0734.jpg',
#  'AllTrain/0247.jpg',
#  'AllTrain/0570.jpg',
#  'AllTrain/0042.jpg',
#  'AllTrain/1000.jpg',
#  'AllTrain/0412.jpg',
#  'AllTrain/0980.jpg',
#  'AllTrain/0217.jpg',
#  'AllTrain/1257.jpg',
#  'AllTrain/0667.jpg',
#  'AllTrain/0126.jpg',
#  'AllTrain/1258.jpg',
#  'AllTrain/0986.jpg',
#  'AllTrain/0398.jpg',
#  'AllTrain/0934.jpg',
#  'AllTrain/0890.jpg',
#  'AllTrain/0429.jpg',
#  'AllTrain/1193.jpg',
#  'AllTrain/0710.jpg',
#  'AllTrain/0907.jpg',
#  'AllTrain/0344.jpg',
#  'AllTrain/0219.jpg',
#  'AllTrain/1102.jpg',
#  'AllTrain/1049.jpg',
#  'AllTrain/0622.jpg',
#  'AllTrain/0690.jpg',
#  'AllTrain/0160.jpg',
#  'AllTrain/0079.jpg',
#  'AllTrain/0782.jpg',
#  'AllTrain/0060.jpg',
#  'AllTrain/0555.jpg',
#  'AllTrain/1101.jpg',
#  'AllTrain/1120.jpg',
#  'AllTrain/1211.jpg',
#  'AllTrain/0976.jpg',
#  'AllTrain/0950.jpg',
#  'AllTrain/1074.jpg',
#  'AllTrain/1241.jpg',
#  'AllTrain/0906.jpg',
#  'AllTrain/0465.jpg',
#  'AllTrain/0842.jpg',
#  'AllTrain/0151.jpg',
#  'AllTrain/1183.jpg',
#  'AllTrain/1092.jpg',
#  'AllTrain/1035.jpg',
#  'AllTrain/1089.jpg',
#  'AllTrain/1081.jpg',
#  'AllTrain/0595.jpg',
#  'AllTrain/0501.jpg',
#  'AllTrain/1277.jpg',
#  'AllTrain/0837.jpg',
#  'AllTrain/0759.jpg',
#  'AllTrain/1208.jpg',
#  'AllTrain/1137.jpg',
#  'AllTrain/1001.jpg',
#  'AllTrain/0543.jpg',
#  'AllTrain/0040.jpg',
#  'AllTrain/1099.jpg',
#  'AllTrain/0272.jpg',
#  'AllTrain/0635.jpg',
#  'AllTrain/0092.jpg',
#  'AllTrain/0540.jpg',
#  'AllTrain/0750.jpg',
#  'AllTrain/1212.jpg',
#  'AllTrain/0753.jpg',
#  'AllTrain/0855.jpg',
#  'AllTrain/0820.jpg',
#  'AllTrain/0674.jpg',
#  'AllTrain/0834.jpg',
#  'AllTrain/0494.jpg',
#  'AllTrain/0112.jpg',
#  'AllTrain/0135.jpg',
#  'AllTrain/0210.jpg',
#  'AllTrain/1003.jpg',
#  'AllTrain/0644.jpg',
#  'AllTrain/0605.jpg',
#  'AllTrain/0209.jpg',
#  'AllTrain/0367.jpg',
#  'AllTrain/1234.jpg',
#  'AllTrain/0724.jpg',
#  'AllTrain/1080.jpg',
#  'AllTrain/0922.jpg',
#  'AllTrain/0714.jpg',
#  'AllTrain/1316.jpg',
#  'AllTrain/0920.jpg',
#  'AllTrain/0233.jpg',
#  'AllTrain/0527.jpg',
#  'AllTrain/0509.jpg',
#  'AllTrain/0020.jpg',
#  'AllTrain/0213.jpg',
#  'AllTrain/0402.jpg',
#  'AllTrain/1198.jpg',
#  'AllTrain/0288.jpg',
#  'AllTrain/0303.jpg',
#  'AllTrain/0390.jpg',
#  'AllTrain/0375.jpg',
#  'AllTrain/0449.jpg',
#  'AllTrain/0636.jpg',
#  'AllTrain/0416.jpg',
#  'AllTrain/0481.jpg',
#  'AllTrain/0361.jpg',
#  'AllTrain/0660.jpg',
#  'AllTrain/0108.jpg',
#  'AllTrain/0983.jpg',
#  'AllTrain/0954.jpg',
#  'AllTrain/0572.jpg',
#  'AllTrain/0328.jpg',
#  'AllTrain/0349.jpg',
#  'AllTrain/1187.jpg',
#  'AllTrain/1100.jpg',
#  'AllTrain/0248.jpg',
#  'AllTrain/0892.jpg',
#  'AllTrain/0441.jpg',
#  'AllTrain/0285.jpg',
#  'AllTrain/0666.jpg',
#  'AllTrain/1233.jpg',
#  'AllTrain/0558.jpg',
#  'AllTrain/1114.jpg',
#  'AllTrain/1227.jpg',
#  'AllTrain/0533.jpg',
#  'AllTrain/0149.jpg',
#  'AllTrain/1294.jpg',
#  'AllTrain/0068.jpg',
#  'AllTrain/0891.jpg',
#  'AllTrain/0325.jpg',
#  'AllTrain/0589.jpg',
#  'AllTrain/1246.jpg',
#  'AllTrain/0846.jpg',
#  'AllTrain/0415.jpg',
#  'AllTrain/0800.jpg',
#  'AllTrain/0921.jpg',
#  'AllTrain/0430.jpg',
#  'AllTrain/0582.jpg',
#  'AllTrain/1192.jpg',
#  'AllTrain/0857.jpg',
#  'AllTrain/0587.jpg',
#  'AllTrain/0297.jpg',
#  'AllTrain/1156.jpg',
#  'AllTrain/1321.jpg',
#  'AllTrain/0744.jpg',
#  'AllTrain/0378.jpg',
#  'AllTrain/0232.jpg',
#  'AllTrain/0656.jpg',
#  'AllTrain/0968.jpg',
#  'AllTrain/0279.jpg',
#  'AllTrain/0178.jpg',
#  'AllTrain/0850.jpg',
#  'AllTrain/0841.jpg',
#  'AllTrain/0292.jpg',
#  'AllTrain/0243.jpg',
#  'AllTrain/0138.jpg',
#  'AllTrain/0811.jpg',
#  'AllTrain/0789.jpg',
#  'AllTrain/1323.jpg',
#  'AllTrain/1271.jpg',
#  'AllTrain/0155.jpg',
#  'AllTrain/0632.jpg',
#  'AllTrain/1140.jpg',
#  'AllTrain/1083.jpg',
#  'AllTrain/0592.jpg',
#  'AllTrain/0451.jpg',
#  'AllTrain/0256.jpg',
#  'AllTrain/1112.jpg',
#  'AllTrain/0246.jpg',
#  'AllTrain/1029.jpg',
#  'AllTrain/0055.jpg',
#  'AllTrain/0381.jpg',
#  'AllTrain/0408.jpg',
#  'AllTrain/0825.jpg',
#  'AllTrain/1174.jpg',
#  'AllTrain/0483.jpg',
#  'AllTrain/0649.jpg',
#  'AllTrain/1068.jpg',
#  'AllTrain/0453.jpg',
#  'AllTrain/1300.jpg',
#  'AllTrain/0331.jpg',
#  'AllTrain/0664.jpg',
#  'AllTrain/0875.jpg',
#  'AllTrain/0987.jpg',
#  'AllTrain/0832.jpg',
#  'AllTrain/1150.jpg',
#  'AllTrain/0598.jpg',
#  'AllTrain/0199.jpg',
#  'AllTrain/0835.jpg',
#  'AllTrain/0645.jpg',
#  'AllTrain/0302.jpg',
#  'AllTrain/0193.jpg',
#  'AllTrain/1220.jpg',
#  'AllTrain/0613.jpg',
#  'AllTrain/0087.jpg',
#  'AllTrain/0774.jpg',
#  'AllTrain/0711.jpg',
#  'AllTrain/0287.jpg',
#  'AllTrain/0682.jpg',
#  'AllTrain/0514.jpg',
#  'AllTrain/0559.jpg',
#  'AllTrain/0480.jpg',
#  'AllTrain/0007.jpg',
#  'AllTrain/0784.jpg',
#  'AllTrain/0577.jpg',
#  'AllTrain/1189.jpg',
#  'AllTrain/1191.jpg',
#  'AllTrain/1058.jpg',
#  'AllTrain/1266.jpg',
#  'AllTrain/0658.jpg',
#  'AllTrain/1188.jpg',
#  'AllTrain/0340.jpg',
#  'AllTrain/0409.jpg',
#  'AllTrain/1110.jpg',
#  'AllTrain/0223.jpg',
#  'AllTrain/1165.jpg',
#  'AllTrain/1062.jpg',
#  'AllTrain/0326.jpg',
#  'AllTrain/0698.jpg',
#  'AllTrain/0448.jpg',
#  'AllTrain/1023.jpg',
#  'AllTrain/0339.jpg',
#  'AllTrain/0730.jpg',
#  'AllTrain/0798.jpg',
#  'AllTrain/0479.jpg',
#  'AllTrain/0502.jpg',
#  'AllTrain/0098.jpg',
#  'AllTrain/0741.jpg',
#  'AllTrain/0172.jpg',
#  'AllTrain/0816.jpg',
#  'AllTrain/0001.jpg',
#  'AllTrain/0113.jpg',
#  'AllTrain/0143.jpg',
#  'AllTrain/0978.jpg',
#  'AllTrain/0169.jpg',
#  'AllTrain/0393.jpg',
#  'AllTrain/0387.jpg',
#  'AllTrain/0180.jpg',
#  'AllTrain/0716.jpg',
#  'AllTrain/0365.jpg',
#  'AllTrain/1269.jpg',
#  'AllTrain/0021.jpg',
#  'AllTrain/0482.jpg',
#  'AllTrain/0520.jpg',
#  'AllTrain/0221.jpg',
#  'AllTrain/1155.jpg',
#  'AllTrain/0854.jpg',
#  'AllTrain/0062.jpg',
#  'AllTrain/0097.jpg',
#  'AllTrain/0972.jpg',
#  'AllTrain/0128.jpg',
#  'AllTrain/1042.jpg',
#  'AllTrain/0630.jpg',
#  'AllTrain/0185.jpg',
#  'AllTrain/0779.jpg',
#  'AllTrain/0791.jpg',
#  'AllTrain/0573.jpg',
#  'AllTrain/0044.jpg',
#  'AllTrain/0541.jpg',
#  'AllTrain/0237.jpg',
#  'AllTrain/0400.jpg',
#  'AllTrain/0396.jpg',
#  'AllTrain/1109.jpg',
#  'AllTrain/0700.jpg',
#  'AllTrain/0054.jpg',
#  'AllTrain/0224.jpg',
#  'AllTrain/1184.jpg',
#  'AllTrain/0743.jpg',
#  'AllTrain/0747.jpg',
#  'AllTrain/0452.jpg',
#  'AllTrain/1030.jpg',
#  'AllTrain/0266.jpg',
#  'AllTrain/0524.jpg',
#  'AllTrain/1310.jpg',
#  'AllTrain/0422.jpg',
#  'AllTrain/0826.jpg',
#  'AllTrain/0032.jpg',
#  'AllTrain/0031.jpg',
#  'AllTrain/0227.jpg',
#  'AllTrain/0222.jpg',
#  'AllTrain/0090.jpg',
#  'AllTrain/1181.jpg',
#  'AllTrain/0242.jpg',
#  'AllTrain/0136.jpg',
#  'AllTrain/0683.jpg',
#  'AllTrain/0659.jpg',
#  'AllTrain/1253.jpg',
#  'AllTrain/1218.jpg',
#  'AllTrain/1292.jpg',
#  'AllTrain/0338.jpg',
#  'AllTrain/0234.jpg',
#  'AllTrain/0175.jpg',
#  'AllTrain/1153.jpg',
#  'AllTrain/1203.jpg',
#  'AllTrain/1149.jpg',
#  'AllTrain/1034.jpg',
#  'AllTrain/0864.jpg',
#  'AllTrain/0386.jpg',
#  'AllTrain/1106.jpg',
#  'AllTrain/0885.jpg',
#  'AllTrain/1132.jpg',
#  'AllTrain/0944.jpg',
#  'AllTrain/0655.jpg',
#  'AllTrain/0231.jpg',
#  'AllTrain/0228.jpg',
#  'AllTrain/0076.jpg',
#  'AllTrain/0908.jpg',
#  'AllTrain/0360.jpg',
#  'AllTrain/0257.jpg',
#  'AllTrain/0844.jpg',
#  'AllTrain/1299.jpg',
#  'AllTrain/0320.jpg',
#  'AllTrain/0207.jpg',
#  'AllTrain/1037.jpg',
#  'AllTrain/0238.jpg',
#  'AllTrain/0665.jpg',
#  'AllTrain/1147.jpg',
#  'AllTrain/0601.jpg',
#  'AllTrain/0335.jpg',
#  'AllTrain/0466.jpg',
#  'AllTrain/0152.jpg',
#  'AllTrain/0459.jpg',
#  'AllTrain/0165.jpg',
#  'AllTrain/0578.jpg',
#  'AllTrain/1090.jpg',
#  'AllTrain/0873.jpg',
#  'AllTrain/0124.jpg',
#  'AllTrain/0463.jpg',
#  'AllTrain/0168.jpg',
#  'AllTrain/0005.jpg',
#  'AllTrain/1006.jpg',
#  'AllTrain/1311.jpg',
#  'AllTrain/0534.jpg',
#  'AllTrain/1245.jpg',
#  'AllTrain/0084.jpg',
#  'AllTrain/0101.jpg',
#  'AllTrain/0580.jpg',
#  'AllTrain/1200.jpg',
#  'AllTrain/0190.jpg',
#  'AllTrain/1046.jpg',
#  'AllTrain/0445.jpg',
#  'AllTrain/0354.jpg',
#  'AllTrain/0643.jpg',
#  'AllTrain/0603.jpg',
#  'AllTrain/0103.jpg',
#  'AllTrain/0218.jpg',
#  'AllTrain/0023.jpg',
#  'AllTrain/0566.jpg',
#  'AllTrain/1256.jpg',
#  'AllTrain/0984.jpg',
#  'AllTrain/1260.jpg',
#  'AllTrain/1050.jpg',
#  'AllTrain/1217.jpg',
#  'AllTrain/0911.jpg',
#  'AllTrain/0999.jpg',
#  'AllTrain/0330.jpg',
#  'AllTrain/0118.jpg',
#  'AllTrain/1317.jpg',
#  'AllTrain/0554.jpg',
#  'AllTrain/0537.jpg',
#  'AllTrain/0345.jpg',
#  'AllTrain/0640.jpg',
#  'AllTrain/0615.jpg',
#  'AllTrain/0642.jpg',
#  'AllTrain/1044.jpg',
#  'AllTrain/0034.jpg',
#  'AllTrain/0122.jpg',
#  'AllTrain/1306.jpg',
#  'AllTrain/0579.jpg',
#  'AllTrain/0852.jpg',
#  'AllTrain/0994.jpg',
#  'AllTrain/0417.jpg',
#  'AllTrain/0332.jpg',
#  'AllTrain/0939.jpg',
#  'AllTrain/0614.jpg',
#  'AllTrain/0719.jpg',
#  'AllTrain/0998.jpg',
#  'AllTrain/0652.jpg',
#  'AllTrain/0058.jpg',
#  'AllTrain/0432.jpg',
#  'AllTrain/1010.jpg',
#  'AllTrain/0772.jpg',
#  'AllTrain/0530.jpg',
#  'AllTrain/0511.jpg',
#  'AllTrain/1318.jpg',
#  'AllTrain/1242.jpg',
#  'AllTrain/0545.jpg',
#  'AllTrain/1129.jpg',
#  'AllTrain/0131.jpg',
#  'AllTrain/0323.jpg',
#  'AllTrain/0627.jpg',
#  'AllTrain/0623.jpg',
#  'AllTrain/0487.jpg',
#  'AllTrain/1180.jpg',
#  'AllTrain/0951.jpg',
#  'AllTrain/0018.jpg',
#  'AllTrain/0693.jpg',
#  'AllTrain/1307.jpg',
#  'AllTrain/0948.jpg',
#  'AllTrain/0617.jpg',
#  'AllTrain/0799.jpg',
#  'AllTrain/0612.jpg',
#  'AllTrain/0985.jpg',
#  'AllTrain/0648.jpg',
#  'AllTrain/0263.jpg',
#  'AllTrain/0768.jpg',
#  'AllTrain/0754.jpg',
#  'AllTrain/0550.jpg',
#  'AllTrain/0813.jpg',
#  'AllTrain/0551.jpg',
#  'AllTrain/0604.jpg',
#  'AllTrain/1305.jpg',
#  'AllTrain/1270.jpg',
#  'AllTrain/0394.jpg',
#  'AllTrain/1143.jpg',
#  'AllTrain/0083.jpg',
#  'AllTrain/0943.jpg',
#  'AllTrain/0905.jpg',
#  'AllTrain/1252.jpg',
#  'AllTrain/0371.jpg',
#  'AllTrain/0244.jpg',
#  'AllTrain/0318.jpg',
#  'AllTrain/0462.jpg',
#  'AllTrain/0296.jpg',
#  'AllTrain/0941.jpg',
#  'AllTrain/0707.jpg',
#  'AllTrain/1094.jpg',
#  'AllTrain/0900.jpg',
#  'AllTrain/0059.jpg',
#  'AllTrain/1087.jpg',
#  'AllTrain/0478.jpg',
#  'AllTrain/0182.jpg',
#  'AllTrain/1185.jpg',
#  'AllTrain/0196.jpg',
#  'AllTrain/0544.jpg',
#  'AllTrain/0410.jpg',
#  'AllTrain/0391.jpg',
#  'AllTrain/0009.jpg',
#  'AllTrain/1014.jpg',
#  'AllTrain/0028.jpg',
#  'AllTrain/0107.jpg',
#  'AllTrain/0946.jpg',
#  'AllTrain/0940.jpg',
#  'AllTrain/0877.jpg',
#  'AllTrain/1091.jpg',
#  'AllTrain/0628.jpg',
#  'AllTrain/0995.jpg',
#  'AllTrain/0468.jpg',
#  'AllTrain/1249.jpg',
#  'AllTrain/0503.jpg',
#  'AllTrain/0153.jpg',
#  'AllTrain/1219.jpg',
#  'AllTrain/0215.jpg',
#  'AllTrain/0026.jpg',
#  'AllTrain/0767.jpg',
#  'AllTrain/0413.jpg',
#  'AllTrain/0493.jpg',
#  'AllTrain/0420.jpg',
#  'AllTrain/1243.jpg',
#  'AllTrain/0104.jpg',
#  'AllTrain/1066.jpg',
#  'AllTrain/0771.jpg',
#  'AllTrain/0162.jpg',
#  'AllTrain/0490.jpg',
#  'AllTrain/0742.jpg',
#  'AllTrain/1144.jpg',
#  'AllTrain/0903.jpg',
#  'AllTrain/0280.jpg',
#  'AllTrain/0715.jpg',
#  'AllTrain/0689.jpg',
#  'AllTrain/0305.jpg',
#  'AllTrain/1060.jpg',
#  'AllTrain/0953.jpg',
#  'AllTrain/0052.jpg',
#  'AllTrain/0966.png',
#  'AllTrain/0787.jpg',
#  'AllTrain/0584.jpg',
#  'AllTrain/0973.jpg',
#  'AllTrain/0316.jpg',
#  'AllTrain/0675.jpg',
#  'AllTrain/1015.jpg',
#  'AllTrain/0513.jpg',
#  'AllTrain/0336.jpg',
#  'AllTrain/1166.jpg',
#  'AllTrain/0456.jpg',
#  'AllTrain/0050.jpg',
#  'AllTrain/1078.jpg',
#  'AllTrain/0176.jpg',
#  'AllTrain/1093.jpg',
#  'AllTrain/0258.jpg',
#  'AllTrain/1164.jpg',
#  'AllTrain/0467.jpg',
#  'AllTrain/1117.jpg',
#  'AllTrain/0374.jpg',
#  'AllTrain/0722.jpg',
#  'AllTrain/0680.jpg',
#  'AllTrain/0334.jpg',
#  'AllTrain/0019.jpg',
#  'AllTrain/0095.jpg',
#  'AllTrain/0308.jpg',
#  'AllTrain/0752.jpg',
#  'AllTrain/1244.jpg',
#  'AllTrain/0142.jpg',
#  'AllTrain/0203.jpg',
#  'AllTrain/0780.jpg',
#  'AllTrain/1259.jpg',
#  'AllTrain/0173.jpg',
#  'AllTrain/1322.jpg',
#  'AllTrain/1281.jpg',
#  'AllTrain/0608.jpg',
#  'AllTrain/0192.jpg',
#  'AllTrain/0405.jpg',
#  'AllTrain/0407.jpg',
#  'AllTrain/0591.jpg',
#  'AllTrain/0472.jpg',
#  'AllTrain/0428.jpg',
#  'AllTrain/1238.jpg',
#  'AllTrain/0831.jpg',
#  'AllTrain/1278.jpg',
#  'AllTrain/0859.jpg',
#  'AllTrain/1032.jpg',
#  'AllTrain/0388.jpg',
#  'AllTrain/0255.jpg',
#  'AllTrain/0049.jpg',
#  'AllTrain/0963.jpg',
#  'AllTrain/1148.jpg',
#  'AllTrain/0188.jpg',
#  'AllTrain/0141.jpg',
#  'AllTrain/0596.jpg',
#  'AllTrain/1086.jpg',
#  'AllTrain/1176.jpg',
#  'AllTrain/0273.jpg',
#  'AllTrain/0662.jpg',
#  'AllTrain/0539.jpg',
#  'AllTrain/0353.jpg',
#  'AllTrain/0132.jpg',
#  'AllTrain/0927.jpg',
#  'AllTrain/0887.jpg',
#  'AllTrain/0935.jpg',
#  'AllTrain/0783.jpg',
#  'AllTrain/0794.jpg',
#  'AllTrain/0535.jpg',
#  'AllTrain/0607.jpg',
#  'AllTrain/0444.jpg',
#  'AllTrain/1275.jpg',
#  'AllTrain/0140.jpg',
#  'AllTrain/0860.jpg',
#  'AllTrain/0359.jpg',
#  'AllTrain/0889.jpg',
#  'AllTrain/1209.jpg',
#  'AllTrain/0557.jpg',
#  'AllTrain/0346.jpg',
#  'AllTrain/0938.jpg',
#  'AllTrain/0070.jpg',
#  'AllTrain/1309.jpg',
#  'AllTrain/1175.jpg',
#  'AllTrain/0492.jpg',
#  'AllTrain/1007.jpg',
#  'AllTrain/0590.jpg',
#  'AllTrain/0306.jpg',
#  'AllTrain/0814.jpg',
#  'AllTrain/1157.jpg',
#  'AllTrain/1098.jpg',
#  'AllTrain/1301.jpg',
#  'AllTrain/0930.jpg',
#  'AllTrain/0974.jpg',
#  'AllTrain/0189.jpg',
#  'AllTrain/0197.jpg',
#  'AllTrain/0419.jpg',
#  'AllTrain/0849.jpg',
#  'AllTrain/0692.jpg',
#  'AllTrain/0817.jpg',
#  'AllTrain/0869.jpg',
#  'AllTrain/0276.jpg',
#  'AllTrain/1146.jpg',
#  'AllTrain/0039.jpg',
#  'AllTrain/0749.jpg',
#  'AllTrain/1216.jpg',
#  'AllTrain/0713.jpg',
#  'AllTrain/0236.jpg',
#  'AllTrain/0395.jpg',
#  'AllTrain/0102.jpg',
#  'AllTrain/1168.jpg',
#  'AllTrain/1154.jpg',
#  'AllTrain/1151.jpg',
#  'AllTrain/0496.jpg',
#  'AllTrain/1158.jpg',
#  'AllTrain/1095.jpg',
#  'AllTrain/0200.jpg',
#  'AllTrain/0111.jpg',
#  'AllTrain/0433.jpg',
#  'AllTrain/0790.jpg',
#  'AllTrain/0294.jpg',
#  'AllTrain/0194.jpg',
#  'AllTrain/0017.jpg',
#  'AllTrain/1076.jpg',
#  'AllTrain/0990.jpg',
#  'AllTrain/0547.jpg',
#  'AllTrain/0679.jpg',
#  'AllTrain/0450.jpg',
#  'AllTrain/1116.jpg',
#  'AllTrain/0475.jpg',
#  'AllTrain/1237.jpg',
#  'AllTrain/0809.jpg',
#  'AllTrain/0435.jpg',
#  'AllTrain/1073.jpg',
#  'AllTrain/0839.jpg',
#  'AllTrain/0746.jpg',
#  'AllTrain/0134.jpg',
#  'AllTrain/0447.jpg',
#  'AllTrain/1232.jpg',
#  'AllTrain/1255.jpg',
#  'AllTrain/0065.jpg',
#  'AllTrain/0067.jpg',
#  'AllTrain/0694.jpg',
#  'AllTrain/0761.jpg',
#  'AllTrain/0561.jpg',
#  'AllTrain/0962.jpg',
#  'AllTrain/0121.jpg',
#  'AllTrain/0355.jpg',
#  'AllTrain/0401.jpg',
#  'AllTrain/0708.jpg',
#  'AllTrain/0510.jpg',
#  'AllTrain/0672.jpg',
#  'AllTrain/0956.jpg',
#  'AllTrain/1064.jpg',
#  'AllTrain/0424.jpg',
#  'AllTrain/1056.jpg',
#  'AllTrain/0872.jpg',
#  'AllTrain/0455.jpg',
#  'AllTrain/1173.jpg',
#  'AllTrain/0003.jpg',
#  'AllTrain/0676.jpg',
#  'AllTrain/0397.jpg',
#  'AllTrain/0732.jpg',
#  'AllTrain/1009.jpg',
#  'AllTrain/0801.jpg',
#  'AllTrain/1247.jpg',
#  'AllTrain/0914.jpg',
#  'AllTrain/0843.jpg',
#  'AllTrain/0379.jpg',
#  'AllTrain/0470.jpg',
#  'AllTrain/0878.jpg',
#  'AllTrain/1167.jpg',
#  'AllTrain/1263.jpg',
#  'AllTrain/0211.jpg',
#  'AllTrain/0086.jpg',
#  'AllTrain/0439.jpg',
#  'AllTrain/1141.jpg',
#  'AllTrain/0836.jpg',
#  'AllTrain/0195.jpg',
#  'AllTrain/0546.jpg',
#  'AllTrain/0291.jpg',
#  'AllTrain/0348.jpg',
#  'AllTrain/0283.jpg',
#  'AllTrain/0569.jpg',
#  'AllTrain/0870.jpg',
#  'AllTrain/1113.jpg',
#  'AllTrain/0898.jpg',
#  'AllTrain/0993.jpg',
#  'AllTrain/0310.jpg',
#  'AllTrain/1021.jpg',
#  'AllTrain/0969.jpg',
#  'AllTrain/0164.jpg',
#  'AllTrain/1134.jpg',
#  'AllTrain/0802.jpg',
#  'AllTrain/0314.jpg',
#  'AllTrain/0525.jpg',
#  'AllTrain/0991.jpg',
#  'AllTrain/0574.jpg',
#  'AllTrain/0996.jpg',
#  'AllTrain/1054.jpg',
#  'AllTrain/0342.jpg',
#  'AllTrain/0253.jpg',
#  'AllTrain/0806.jpg',
#  'AllTrain/1230.jpg',
#  'AllTrain/1161.jpg',
#  'AllTrain/1145.jpg',
#  'AllTrain/0056.jpg',
#  'AllTrain/1250.jpg',
#  'AllTrain/0504.jpg',
#  'AllTrain/1038.jpg',
#  'AllTrain/0965.jpg',
#  'AllTrain/1170.jpg',
#  'AllTrain/0075.jpg',
#  'AllTrain/0879.jpg',
#  'AllTrain/1172.jpg',
#  'AllTrain/0206.jpg',
#  'AllTrain/0626.jpg',
#  'AllTrain/0013.jpg',
#  'AllTrain/0319.jpg',
#  'AllTrain/0139.jpg',
#  'AllTrain/0489.jpg',
#  'AllTrain/0937.jpg',
#  'AllTrain/0036.jpg',
#  'AllTrain/1315.jpg',
#  'AllTrain/0389.jpg',
#  'AllTrain/0712.jpg',
#  'AllTrain/0425.jpg',
#  'AllTrain/0088.jpg',
#  'AllTrain/0932.jpg',
#  'AllTrain/0536.jpg',
#  'AllTrain/0022.jpg',
#  'AllTrain/0078.jpg',
#  'AllTrain/1160.jpg',
#  'AllTrain/0011.jpg',
#  'AllTrain/1206.jpg',
#  'AllTrain/1079.jpg',
#  'AllTrain/0677.jpg',
#  'AllTrain/0764.jpg',
#  'AllTrain/0765.jpg',
#  'AllTrain/0755.jpg',
#  'AllTrain/1067.jpg',
#  'AllTrain/0975.jpg',
#  'AllTrain/0726.jpg',
#  'AllTrain/0041.jpg',
#  'AllTrain/0364.jpg',
#  'AllTrain/0797.jpg',
#  'AllTrain/0329.jpg',
#  'AllTrain/0571.jpg',
#  'AllTrain/0208.jpg',
#  'AllTrain/0804.jpg',
#  'AllTrain/0845.jpg',
#  'AllTrain/0457.jpg',
#  'AllTrain/1213.jpg',
#  'AllTrain/0901.jpg',
#  'AllTrain/0609.jpg',
#  'AllTrain/0703.jpg',
#  'AllTrain/0278.jpg',
#  'AllTrain/0307.jpg',
#  'AllTrain/0641.jpg',
#  'AllTrain/1280.jpg',
#  'AllTrain/0301.jpg',
#  'AllTrain/0866.jpg',
#  'AllTrain/0461.jpg',
#  'AllTrain/0992.jpg',
#  'AllTrain/0362.jpg',
#  'AllTrain/0347.jpg',
#  'AllTrain/0363.jpg',
#  'AllTrain/0317.jpg',
#  'AllTrain/1201.jpg',
#  'AllTrain/1248.jpg',
#  'AllTrain/0006.jpg',
#  'AllTrain/0521.jpg',
#  'AllTrain/0241.jpg',
#  'AllTrain/1025.jpg',
#  'AllTrain/1186.jpg',
#  'AllTrain/0171.jpg',
#  'AllTrain/0170.jpg',
#  'AllTrain/0235.jpg',
#  'AllTrain/0064.jpg',
#  'AllTrain/0186.jpg',
#  'AllTrain/0529.jpg',
#  'AllTrain/0495.jpg',
#  'AllTrain/0351.jpg',
#  'AllTrain/0125.jpg',
#  'AllTrain/0229.jpg',
#  'AllTrain/0002.jpg',
#  'AllTrain/0621.jpg',
#  'AllTrain/0262.jpg',
#  'AllTrain/1293.jpg',
#  'AllTrain/0967.jpg',
#  'AllTrain/1169.jpg',
#  'AllTrain/1254.jpg',
#  'AllTrain/1162.jpg',
#  'AllTrain/0600.jpg',
#  'AllTrain/0377.jpg',
#  'AllTrain/0147.jpg',
#  'AllTrain/1225.jpg',
#  'AllTrain/1119.jpg',
#  'AllTrain/0048.jpg',
#  'AllTrain/0881.jpg',
#  'AllTrain/0793.jpg',
#  'AllTrain/0446.jpg',
#  'AllTrain/0757.jpg',
#  'AllTrain/0454.jpg',
#  'AllTrain/1325.jpg',
#  'AllTrain/0163.jpg',
#  'AllTrain/0616.jpg',
#  'AllTrain/0624.jpg',
#  'AllTrain/0073.jpg',
#  'AllTrain/1082.jpg',
#  'AllTrain/0304.jpg',
#  'AllTrain/0313.jpg',
#  'AllTrain/0358.jpg',
#  'AllTrain/0286.jpg',
#  'AllTrain/0633.jpg',
#  'AllTrain/0130.jpg',
#  'AllTrain/0321.jpg',
#  'AllTrain/0766.jpg',
#  'AllTrain/1215.jpg',
#  'AllTrain/0201.jpg',
#  'AllTrain/1235.jpg',
#  'AllTrain/0264.jpg',
#  'AllTrain/1159.jpg',
#  'AllTrain/0888.jpg',
#  'AllTrain/0918.jpg',
#  'AllTrain/0970.jpg',
#  'AllTrain/1308.jpg',
#  'AllTrain/0862.jpg',
#  'AllTrain/0563.jpg',
#  'AllTrain/0957.jpg',
#  'AllTrain/1251.jpg',
#  'AllTrain/0159.jpg',
#  'AllTrain/0568.jpg',
#  'AllTrain/1261.jpg',
#  'AllTrain/0216.jpg',
#  'AllTrain/1069.jpg',
#  'AllTrain/0497.jpg',
#  'AllTrain/1304.jpg',
#  'AllTrain/0214.jpg',
#  'AllTrain/0883.jpg',
#  'AllTrain/0352.jpg',
#  'AllTrain/0871.jpg',
#  'AllTrain/0443.jpg',
#  'AllTrain/0114.jpg',
#  'AllTrain/0061.jpg',
#  'AllTrain/1291.jpg',
#  'AllTrain/0275.jpg',
#  'AllTrain/1295.jpg',
#  'AllTrain/0823.jpg',
#  'AllTrain/0928.jpg',
#  'AllTrain/0271.jpg',
#  'AllTrain/0924.jpg',
#  'AllTrain/1197.jpg',
#  'AllTrain/0775.jpg',
#  'AllTrain/0116.jpg',
#  'AllTrain/0240.jpg',
#  'AllTrain/0202.jpg',
#  'AllTrain/1226.jpg',
#  'AllTrain/0204.jpg',
#  'AllTrain/0267.jpg',
#  'AllTrain/1130.jpg',
#  'AllTrain/0517.jpg',
#  'AllTrain/0597.jpg',
#  'AllTrain/0038.jpg',
#  'AllTrain/0893.jpg',
#  'AllTrain/1041.jpg',
#  'AllTrain/0756.jpg',
#  'AllTrain/0406.jpg',
#  'AllTrain/0848.jpg',
#  'AllTrain/1096.jpg',
#  'AllTrain/0333.jpg',
#  'AllTrain/0684.jpg',
#  'AllTrain/1028.jpg',
#  'AllTrain/0284.jpg',
#  'AllTrain/1236.jpg',
#  'AllTrain/0053.jpg',
#  'AllTrain/0093.jpg',
#  'AllTrain/0738.jpg',
#  'AllTrain/0289.jpg',
#  'AllTrain/1124.jpg',
#  'AllTrain/0858.jpg',
#  'AllTrain/0014.jpg',
#  'AllTrain/0251.jpg',
#  'AllTrain/1105.jpg',
#  'AllTrain/0796.jpg',
#  'AllTrain/0274.jpg',
#  'AllTrain/0585.jpg',
#  'AllTrain/0259.jpg',
#  'AllTrain/0442.jpg',
#  'AllTrain/1123.jpg',
#  'AllTrain/1285.jpg',
#  'AllTrain/1059.jpg',
#  'AllTrain/0695.jpg',
#  'AllTrain/1072.jpg',
#  'AllTrain/0657.jpg',
#  'AllTrain/0440.jpg',
#  'AllTrain/1326.jpg',
#  'AllTrain/1279.jpg',
#  'AllTrain/0827.jpg',
#  'AllTrain/0127.jpg',
#  'AllTrain/0506.jpg',
#  'AllTrain/0737.jpg',
#  'AllTrain/0942.jpg',
#  'AllTrain/1196.jpg',
#  'AllTrain/0464.jpg',
#  'AllTrain/0549.jpg',
#  'AllTrain/0762.jpg',
#  'AllTrain/0144.jpg',
#  'AllTrain/1045.jpg',
#  'AllTrain/0909.jpg',
#  'AllTrain/0404.jpg',
#  'AllTrain/0803.jpg',
#  'AllTrain/1047.jpg',
#  'AllTrain/0637.jpg',
#  'AllTrain/1040.jpg',
#  'AllTrain/0518.jpg',
#  'AllTrain/0436.jpg',
#  'AllTrain/0133.jpg',
#  'AllTrain/0819.jpg',
#  'AllTrain/0181.jpg',
#  'AllTrain/0989.jpg',
#  'AllTrain/1152.jpg',
#  'AllTrain/0156.jpg',
#  'AllTrain/0290.jpg',
#  'AllTrain/1065.jpg',
#  'AllTrain/0528.jpg',
#  'AllTrain/0668.jpg',
#  'AllTrain/0298.jpg',
#  'AllTrain/1063.jpg',
#  'AllTrain/0519.jpg',
#  'AllTrain/1071.jpg',
#  'AllTrain/0158.jpg',
#  'AllTrain/0936.jpg',
#  'AllTrain/0840.jpg',
#  'AllTrain/0324.jpg',
#  'AllTrain/0915.jpg',
#  'AllTrain/1004.jpg',
#  'AllTrain/0337.jpg',
#  'AllTrain/0460.jpg',
#  'AllTrain/1290.jpg',
#  'AllTrain/0639.jpg',
#  'AllTrain/0654.jpg',
#  'AllTrain/0896.jpg',
#  'AllTrain/0269.jpg',
#  'AllTrain/1135.jpg',
#  'AllTrain/1024.jpg',
#  'AllTrain/0926.jpg',
#  'AllTrain/1171.jpg',
#  'AllTrain/1190.jpg',
#  'AllTrain/1287.jpg',
#  'AllTrain/0254.jpg',
#  'AllTrain/0105.jpg',
#  'AllTrain/0886.jpg',
#  'AllTrain/0137.jpg',
#  'AllTrain/0029.jpg',
#  'AllTrain/0933.jpg',
#  'AllTrain/1327.jpg',
#  'AllTrain/0343.jpg',
#  'AllTrain/1202.jpg',
#  'AllTrain/0647.jpg',
#  'AllTrain/0370.jpg',
#  'AllTrain/0499.jpg',
#  'AllTrain/0261.jpg',
#  'AllTrain/1097.jpg',
#  'AllTrain/0575.jpg',
#  'AllTrain/0421.jpg',
#  'AllTrain/1240.jpg',
#  'AllTrain/0867.jpg',
#  'AllTrain/1016.jpg',
#  'AllTrain/0894.jpg',
#  'AllTrain/0516.jpg',
#  'AllTrain/0681.jpg',
#  'AllTrain/1128.jpg',
#  'AllTrain/1118.jpg',
#  'AllTrain/0146.jpg',
#  'AllTrain/1267.jpg',
#  'AllTrain/1222.jpg',
#  'AllTrain/0260.jpg',
#  'AllTrain/0486.jpg',
#  'AllTrain/0977.jpg',
#  'AllTrain/0728.jpg',
#  ...]

# %%
from distutils.dir_util import copy_tree
toDir = "AllValid"
fromdir = "/content/data/valid/Autistic"
copy_tree(fromdir ,toDir)
fromdirNon = "/content/data/valid/Non_Autistic"
copy_tree(fromdirNon ,toDir)
# Out:
# ['AllValid/38.jpg',
#  'AllValid/19.jpg',
#  'AllValid/12.jpg',
#  'AllValid/18.jpg',
#  'AllValid/08.jpg',
#  'AllValid/23.jpg',
#  'AllValid/40.jpg',
#  'AllValid/28.jpg',
#  'AllValid/35.jpg',
#  'AllValid/01.jpg',
#  'AllValid/11.jpg',
#  'AllValid/26.jpg',
#  'AllValid/34.jpg',
#  'AllValid/10.jpg',
#  'AllValid/27.jpg',
#  'AllValid/33.png',
#  'AllValid/22.jpg',
#  'AllValid/15.jpg',
#  'AllValid/20.jpg',
#  'AllValid/06.jpg',
#  'AllValid/02.jpg',
#  'AllValid/13.jpg',
#  'AllValid/24.jpg',
#  'AllValid/09.jpg',
#  'AllValid/29.jpg',
#  'AllValid/31.jpg',
#  'AllValid/37.jpg',
#  'AllValid/32.jpg',
#  'AllValid/03.jpg',
#  'AllValid/16.jpg',
#  'AllValid/04.jpg',
#  'AllValid/07.jpg',
#  'AllValid/30.jpg',
#  'AllValid/17.jpg',
#  'AllValid/21.jpg',
#  'AllValid/14.jpg',
#  'AllValid/05.jpg',
#  'AllValid/25.jpg',
#  'AllValid/36.jpg',
#  'AllValid/39.jpg']

# %%
from distutils.dir_util import copy_tree
toDir = "AllTest"
fromdir = "/content/data/test/Autistic"
copy_tree(fromdir ,toDir)
fromdirNon = "/content/data/test/Non_Autistic"
copy_tree(fromdirNon ,toDir)
# Out:
# ['AllTest/033.jpg',
#  'AllTest/053.jpg',
#  'AllTest/047.jpg',
#  'AllTest/034.jpg',
#  'AllTest/099.jpg',
#  'AllTest/129.jpg',
#  'AllTest/070.jpg',
#  'AllTest/050.jpg',
#  'AllTest/084.jpg',
#  'AllTest/025.jpg',
#  'AllTest/128.jpg',
#  'AllTest/091.jpg',
#  'AllTest/122.jpg',
#  'AllTest/012.jpg',
#  'AllTest/140.jpg',
#  'AllTest/048.jpg',
#  'AllTest/006.jpg',
#  'AllTest/043.jpg',
#  'AllTest/028.jpg',
#  'AllTest/056.jpg',
#  'AllTest/031.jpg',
#  'AllTest/127.jpg',
#  'AllTest/042.jpg',
#  'AllTest/090.jpg',
#  'AllTest/044.jpg',
#  'AllTest/106.jpg',
#  'AllTest/051.jpg',
#  'AllTest/125.jpg',
#  'AllTest/037.jpg',
#  'AllTest/096.jpg',
#  'AllTest/081.jpg',
#  'AllTest/023.jpg',
#  'AllTest/123.jpg',
#  'AllTest/062.jpg',
#  'AllTest/049.jpg',
#  'AllTest/002.jpg',
#  'AllTest/052.jpg',
#  'AllTest/040.jpg',
#  'AllTest/124.jpg',
#  'AllTest/005.jpg',
#  'AllTest/039.jpg',
#  'AllTest/121.jpg',
#  'AllTest/009.jpg',
#  'AllTest/014.jpg',
#  'AllTest/022.jpg',
#  'AllTest/003.jpg',
#  'AllTest/126.jpg',
#  'AllTest/016.jpg',
#  'AllTest/038.jpg',
#  'AllTest/021.jpg',
#  'AllTest/136.jpg',
#  'AllTest/066.jpg',
#  'AllTest/112.jpg',
#  'AllTest/120.jpg',
#  'AllTest/100.jpg',
#  'AllTest/132.jpg',
#  'AllTest/103.jpg',
#  'AllTest/036.jpg',
#  'AllTest/007.jpg',
#  'AllTest/054.jpg',
#  'AllTest/032.jpg',
#  'AllTest/082.jpg',
#  'AllTest/061.jpg',
#  'AllTest/110.jpg',
#  'AllTest/008.jpg',
#  'AllTest/029.jpg',
#  'AllTest/063.jpg',
#  'AllTest/086.jpg',
#  'AllTest/024.jpg',
#  'AllTest/105.jpg',
#  'AllTest/115.jpg',
#  'AllTest/117.jpg',
#  'AllTest/094.jpg',
#  'AllTest/109.jpg',
#  'AllTest/069.jpg',
#  'AllTest/019.jpg',
#  'AllTest/104.jpg',
#  'AllTest/085.jpg',
#  'AllTest/055.jpg',
#  'AllTest/098.jpg',
#  'AllTest/137.jpg',
#  'AllTest/088.jpg',
#  'AllTest/114.jpg',
#  'AllTest/013.jpg',
#  'AllTest/015.jpg',
#  'AllTest/020.jpg',
#  'AllTest/035.jpg',
#  'AllTest/078.jpg',
#  'AllTest/101.jpg',
#  'AllTest/017.jpg',
#  'AllTest/072.jpg',
#  'AllTest/116.jpg',
#  'AllTest/083.jpg',
#  'AllTest/119.jpg',
#  'AllTest/011.jpg',
#  'AllTest/059.jpg',
#  'AllTest/068.jpg',
#  'AllTest/139.jpg',
#  'AllTest/133.jpg',
#  'AllTest/058.jpg',
#  'AllTest/057.jpg',
#  'AllTest/102.jpg',
#  'AllTest/076.jpg',
#  'AllTest/138.jpg',
#  'AllTest/108.jpg',
#  'AllTest/113.jpg',
#  'AllTest/087.jpg',
#  'AllTest/075.jpg',
#  'AllTest/097.jpg',
#  'AllTest/004.jpg',
#  'AllTest/071.jpg',
#  'AllTest/118.jpg',
#  'AllTest/111.jpg',
#  'AllTest/074.jpg',
#  'AllTest/065.jpg',
#  'AllTest/064.jpg',
#  'AllTest/045.jpg',
#  'AllTest/026.jpg',
#  'AllTest/073.jpg',
#  'AllTest/041.jpg',
#  'AllTest/018.jpg',
#  'AllTest/067.jpg',
#  'AllTest/079.jpg',
#  'AllTest/060.jpg',
#  'AllTest/077.jpg',
#  'AllTest/134.jpg',
#  'AllTest/131.jpg',
#  'AllTest/046.jpg',
#  'AllTest/080.jpg',
#  'AllTest/089.jpg',
#  'AllTest/001.jpg',
#  'AllTest/095.jpg',
#  'AllTest/107.jpg',
#  'AllTest/135.jpg',
#  'AllTest/130.jpg',
#  'AllTest/027.jpg',
#  'AllTest/030.jpg',
#  'AllTest/092.jpg',
#  'AllTest/010.jpg',
#  'AllTest/093.jpg']

# %%
filenames = []
categories = []
Train_autistic = os.listdir("/content/data/train/Autistic/")
for filename in Train_autistic :
        categories.append(1)
filenames.extend(Train_autistic )

Train_non_autistic = os.listdir("/content/data/train/Non_Autistic/")
for filename in Train_non_autistic :
        categories.append(0)
filenames.extend(Train_non_autistic )

train_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

train_df["category"] = train_df["category"].replace({0: 'non_autistic', 1: 'autistic'})

# %%
filenames2 = []
categories2= []
valid_autistic = os.listdir("/content/data/valid/Autistic/")
for filename in valid_autistic :
        categories2.append(1)
filenames2.extend(valid_autistic )

valid_non_autistic = os.listdir("/content/data/valid/Non_Autistic/")
for filename in valid_non_autistic :
        categories2.append(0)
filenames2.extend(valid_non_autistic )

valid_df = pd.DataFrame({
    'filename': filenames2,
    'category': categories2
})

valid_df["category"] = valid_df["category"].replace({0: 'non_autistic', 1: 'autistic'})

# %%
filenames3 = []
categories3 = []
Test_autistic = os.listdir("/content/data/test/Autistic/")
for filename in Test_autistic :
        categories3.append(1)
filenames3.extend(Test_autistic )

Test_non_autistic = os.listdir("/content/data/test/Non_Autistic/")
for filename in Test_non_autistic :
        categories3.append(0)
filenames3.extend(Test_non_autistic )

test_df = pd.DataFrame({
    'filename': filenames3,
    'category': categories3
})

test_df["category"] = test_df["category"].replace({0: 'non_autistic', 1: 'autistic'})

# %%
train_datagen = ImageDataGenerator(rotation_range=15,
                                rescale=1./255,
                                shear_range=0.1,
                                zoom_range=0.2,
                                horizontal_flip=True,
                                width_shift_range=0.1,
                                height_shift_range=0.1
                                )

# %%
total_train=train_df.shape[0]
total_validate=valid_df.shape[0]
batch_size = 64

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df, "AllTrain/", 
    x_col='filename',
    y_col='category',
    target_size=Image_Size,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 2654 validated image filenames belonging to 2 classes.

# %%
valid_generator = train_datagen.flow_from_dataframe(
    valid_df, "AllValid/", 
    x_col='filename',
    y_col='category',
    target_size=Image_Size,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 80 validated image filenames belonging to 2 classes.

# %%
test_generator = train_datagen.flow_from_dataframe(test_df,
                                                 "AllTest/",x_col='filename',y_col='category',
                                                 target_size=Image_Size,
                                                 class_mode='categorical',
                                                 batch_size=batch_size)
# Out:
# Found 280 validated image filenames belonging to 2 classes.

# %%
test_generator

# %%
X_test, y_test = next(test_generator)

# %%
x_valid, y_valid = next(valid_generator)

# %%
X_test.shape
# Out:
# (64, 128, 128, 3)

# %%
y_test.shape
# Out:
# (64, 2)

# %%
epochs=30
history = model1.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=valid_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 41/41 [==============================] - 54s 544ms/step - loss: 1.3888 - accuracy: 0.5154 - val_loss: 0.7476 - val_accuracy: 0.4531
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 2/30
# 41/41 [==============================] - 22s 524ms/step - loss: 1.0236 - accuracy: 0.5046 - val_loss: 0.8253 - val_accuracy: 0.4844
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 27/30
# 41/41 [==============================] - 20s 493ms/step - loss: 0.7046 - accuracy: 0.4969 - val_loss: 0.6929 - val_accuracy: 0.5156
# Epoch 28/30
# 41/41 [==============================] - 20s 491ms/step - loss: 0.7057 - accuracy: 0.4726 - val_loss: 0.6940 - val_accuracy: 0.5000

# %%
model5.save(filepath5)

# %%
from keras.models import load_model

# %%
# create list of loaded models use  load_model() 
all_models = list()
for i in range(5):
  filename = '/content/drive/MyDrive/Autism/weights/model'+str(i+1)+'.h5'
  model = load_model(filename)
  all_models.append(model)

# %%
print(len(all_models))
# Out:
# 5

# %%
# stacked generalization with linear meta model on blobs dataset
from sklearn.datasets import make_blobs
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from keras.models import load_model
from tensorflow.keras.utils import to_categorical
from numpy import dstack

# %%
# create stacked model input dataset as outputs from the ensemble
def stacked_dataset(members, inputX):
	stackX = None
	for model in members:
		# make prediction
		yhat = model.predict(inputX, verbose=0)
		# stack predictions into [rows, members, probabilities]
		if stackX is None:
			stackX = yhat
		else:
			stackX = dstack((stackX, yhat))
	# flatten predictions to [rows, members x probabilities]
	stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
	return stackX

# %%
# define stacked model from multiple member input models
def define_stacked_model(members):
	# update all layers in all models to not be trainable
	for i in range(len(members)):
		model = members[i]
		for layer in model.layers:
			# make not trainable
			layer.trainable = False
			# rename to avoid 'unique layer name' issue
			layer._name = 'ensemble_' + str(i+1) + '_' + layer.name
	# define multi-headed input
	ensemble_visible = [model.input for model in members]
	# concatenate merge output from each model
	ensemble_outputs = [model.output for model in members]
	merge = concatenate(ensemble_outputs)
	hidden = Dense(10, activation='relu')(merge)
	output = Dense(5, activation='softmax')(hidden)
	model = Model(inputs=ensemble_visible, outputs=output)
	# plot graph of ensemble
	plot_model(model, show_shapes=True, to_file='model_graph.png')
	# compile
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# %%
# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy):
	# create dataset using ensemble
  stackedX = stacked_dataset(members, inputX)
	# fit standalone model
  model = DecisionTreeClassifier()
  model.fit(stackedX, inputy)
  return model

# %%
# fit stacked model using the ensemble
model = fit_stacked_model(all_models, x_valid, y_valid)

# %%
X_test.shape
# Out:
# (64, 128, 128, 3)

# %%
y_test.shape
# Out:
# (64, 2)

# %%
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	yhat = model.predict(stackedX)
	return yhat

# %%
# make a prediction with a stacked model
def predict_stacked_model(model, inputX):
	# prepare input data
	X = [inputX for _ in range(len(model.input))]
	# make prediction
	return model.predict(X, verbose=0)

# %%
from keras.layers import concatenate

# %%
# stacked generalization with linear meta model on blobs dataset
from sklearn.datasets import make_blobs
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from keras.models import load_model
from tensorflow.keras.utils import to_categorical
from numpy import dstack

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
yhat = stacked_prediction(all_models, model, X_test)

# %%
acc = accuracy_score(y_test, yhat)
print('Stacked Test Accuracy: %.3f' % acc)
# Out:
# Stacked Test Accuracy: 0.469
